# %% [markdown]
# ## BASIC LEVEL ARRAY PROBLEMS

# %% [markdown]
# # Alternate elements of an array
#
# Given an array arr[], the task is to print every alternate element of the array starting from the first element.
#
# Examples:
#
# Input: arr[] = [10, 20, 30, 40, 50]
# Output: 10 30 50
# Explanation: Print the first element (10), skip the second element (20), print the third element (30), skip the fourth element(40) and print the fifth element(50).
#
# Input: arr[] = [-5, 1, 4, 2, 12]
# Output: -5 4 12

# %%
def PrintAlternate(a):
    n=len(a)
    res=[]
    for i in range(0,n,2):
        res.append(a[i])
    return res
a=[10,20,30,40,50]
print(PrintAlternate(a))
# Time Complexity: O(n), where n is the number of elements in arr[].
# Auxiliary Space: O(1)
# Out:
# [10, 30, 50]

# %%
def PrintAlternateRec(a,idx,res):
    n=len(a)
    if idx<n:
       res.append[a[idx]]
       PrintAlternateRec(a,idx+2,res)
def PrintAlternate(a):
    res=[]
    PrintAlternateRec(a,0,res)
    return res

arr = [10, 20, 30, 40, 50]
res = PrintAlternate(arr)
print(" ".join(map(str,res)))  
# Time Complexity: O(n), where n is the number of elements in arr[].
# Auxiliary Space: O(n), for recursive call stack.

# %% [markdown]
# # Leaders in an array
# Given an array arr[] of size n, the task is to find all the Leaders in the array. An element is a Leader if it is greater than or equal to all the elements to its right side.
#
# Note: The rightmost element is always a leader.

# %%
def arrayLeaders(a):
    res=[]
    n=len(a)
    #consider last element as leader
    maxRight=a[-1]
    #add it to result
    res.append(maxRight)
    #traverse array in reverse and check for every element if it is greater than maxRight then append to result
    for i in range(n-2,-1,-1):
        if a[i]>=maxRight:
            maxRight=a[i]
            res.append(maxRight)
    #Reverse the resultant array
    res.reverse()
    return res
arr = [16, 17, 4, 3, 5, 2]
print(arrayLeaders(arr))
# Out:
# [17, 5, 2]

# %% [markdown]
# # Check if an Array is Sorted
#
# Given an array arr[], check if it is sorted in ascending order or not. Equal values are allowed in an array and two consecutive equal values are considered sorted.
#
# Examples:
#
# Input: arr[] = [10, 20, 30, 40, 50]
# Output: true
# Explanation: The given array is sorted.
#
# Input: arr[] = [90, 80, 100, 70, 40, 30]
# Output: false
# Explanation: The given array is not sorted.

# %%
def isSorted(a):
    n=len(a)
    for i in range(1,n):
       if a[i-1]>a[i]:
           return False
    return True
print(isSorted([3,5,9,2,8]))

# Iterative approach - O(n) Time and O(1) Space
# The idea is simple. We start traversing from the second element. For every element we check if it is smaller 
# than or equal to previous element or not. At any point if we find previous element greater, we return false.
# Out:
# False

# %% [markdown]
# # Remove duplicates from Sorted Array
#
# Given a sorted array arr[] of size n, the goal is to rearrange the array so that all distinct elements appear at the beginning in sorted order. Additionally, return the length of this distinct sorted subarray.
#
# Note: The elements after the distinct ones can be in any order and hold any value, as they don't affect the result.
#
# Examples:
#
# Input: arr[] = [2, 2, 2, 2, 2]
# Output: [2]
# Explanation: All the elements are 2, So only keep one instance of 2.
#
# Input: arr[] = [1, 2, 2, 3, 4, 4, 4, 5, 5]
# Output: [1, 2, 3, 4, 5]
#
# Input: arr[] = [1, 2, 3]
# Output: [1, 2, 3]
# Explanation : No change as all elements are distinct.

# %%
def RemoveDuplicates(a):
    n=len(a)
    idx=0
    if n<=1:
        return n
    for i in range(1,n):
        if a[i]!=a[i-1]:
            a[idx]=a[i]
            idx+=1
    return a[:idx]
a=[20,30,30,40,50,50,20]
print(RemoveDuplicates(a))
# Out:
# [30, 40, 50, 20]

# %% [markdown]
# 26. Remove Duplicates from Sorted Array
# Solved
# Easy
# Topics
# premium lock icon
# Companies
# Hint
# Given an integer array nums sorted in non-decreasing order, remove the duplicates in-place such that each unique element appears only once. The relative order of the elements should be kept the same. Then return the number of unique elements in nums.
#
# Consider the number of unique elements of nums to be k, to get accepted, you need to do the following things:
#
# Change the array nums such that the first k elements of nums contain the unique elements in the order they were present in nums initially. The remaining elements of nums are not important as well as the size of nums.
# Return k.

# %%
from typing import List
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        if not nums:
            return 0
        idx = 0
        for i in range(1, len(nums)):
            if nums[i] != nums[idx]:
                idx += 1
                nums[idx] = nums[i]
        return idx + 1
sol=Solution()
nums=[1,1,2]
print(sol.removeDuplicates(nums))
# Out:
# 2

# %% [markdown]
# # Generating All Subarrays
#
# Given an array arr[], the task is to generate all the possible subarrays of the given array.
#
# Examples:
#
# Input: arr[] = [1, 2, 3]
# Output: [ [1], [1, 2], [2], [1, 2, 3], [2, 3], [3] ]
#
# Input: arr[] = [1, 2]
# Output: [ [1], [1, 2], [2] ]

# %%
def PrintAllSubArrays(a,start,end):
    end=len(a)
    if start==end:
        return
    if start>end:
        return  PrintAllSubArrays(a,0,end+1)
    else:
        print(a[start:end+1])
        return PrintAllSubArrays(a,start+1,end)
a=[2,5,7,9]
print(PrintAllSubArrays(a,0,0))
# Out:
# [2, 5, 7, 9]
# [5, 7, 9]
# [7, 9]
# [9]
# None

# %% [markdown]
# Array Reverse
# Last Updated : 08 Aug, 2025
# Reverse an array arr[]. Reversing an array means rearranging the elements such that the first element becomes the last, the second element becomes second last and so on.
#
# Examples:
#
# Input: arr[] = [1, 4, 3, 2, 6, 5]
# Output:  [5, 6, 2, 3, 4, 1]
# Explanation: The first element 1 moves to last position, the second element 4 moves to second-last and so on.
#
# Input: arr[] = [4, 5, 1, 2]
# Output: [2, 1, 5, 4]
# Explanation: The first element 4 moves to last position, the second element 5 moves to second last and so on.

# %%
def ReverseArrUsingTwoPointer(a):
    left=0
    right=len(a)-1
    while left<right:
        a[left],a[right]=a[right],a[left]
        left+=1
        right-=1
    
arr=[3,5,7,9]
ReverseArrUsingTwoPointer(arr)
for i in range(len(arr)):
        print(arr[i], end=" ")
# [Expected Approach - 1] Using Two Pointers - O(n) Time and O(1) Space
# The idea is to maintain two pointers: left and right, such that left points at the beginning of the array and 
# right points to the end of the array. 

# While left pointer is less than the right pointer, swap the elements at these two positions.
# After each swap, increment the left pointer and decrement the right pointer to move towards the center of array. 
# This will swap all the elements in the first half with their corresponding element in the second half.
# Out:
# 9 7 5 3

# %%
def ReverseArrUsingSwap(a):
    n=len(a)
    temp=0
    for i in range(n//2):
        temp=a[i]
        a[i]=a[n-i-1]
        a[n-i-1]=temp
arr=[3,5,7,9]
ReverseArrUsingSwap(arr)
for i in range(len(arr)):
        print(arr[i], end=" ")
# Time Complexity: O(n), the loop runs through half of the array, so it's linear with respect to the array size.
# Auxiliary Space: O(1), no extra space is required, therefore we are reversing the array in-place.
# Out:
# 9 7 5 3

# %% [markdown]
# # left rotate array by one place

# %%
def LeftRotatebyOnePlace(a):
    temp=a[0]
    n=len(a)
    for i in range(1,n):
        a[i-1]=a[i]
    a[n-1]=temp

a=[2,4,6,8]
LeftRotatebyOnePlace(a)
for i in a:
    print(i, end=" ")
# Out:
# 4 6 8 2

# %% [markdown]
# # left rotate array by d places

# %%
def leftRotatebyDPlaces(a,d):
    n=len(a)
    if d>n:
        d%=n
    temp=a[:d] #first d elements to temp
    a[:d]=a[d:]
    a[d:]=temp
    
a=[1,2,3,4,5,6,7] 
d=3
leftRotatebyDPlaces(a,d)
for i in range(len(a)):
    print(a[i], end=" ")
#brute force method TC-O(n+d) SC-O(d)
# Out:
# 4 5 6 1 2 3

# %%
def leftRotatebyDPlaces(a,d):
    n=len(a)
    d%=n
    a[:d]=reversed(a[:d])
    a[d:]=reversed(a[d:])
    a.reverse()
a=[1,2,3,4,5,6,7] 
d=3
leftRotatebyDPlaces(a,d)
for i in range(len(a)):
    print(a[i], end=" ")
# Out:
# 4 5 6 7 1 2 3

# %%
def RightRotatebyDPlaces(a,d):
    n=len(a)
    d%=n
    a.reverse()
    a[:d]=reversed(a[:d])
    a[d:]=reversed(a[d:])
a=[1,2,3,4,5,6,7] 
d=3
RightRotatebyDPlaces(a,d)
for i in range(len(a)):
    print(a[i], end=" ")
# Out:
# 5 6 7 1 2 3 4

# %%
def RightRotatebyDPlaces(arr,d):
    n = len(arr)
    d %= n  # Handle d > n
    temp = arr[-d:]        # Last d elements
    arr[d:] = arr[:-d]     # Shift first n-d elements to the right
    arr[:d] = temp         # move temp to first
a=[1,2,3,4,5,6,7]          
d=3
RightRotatebyDPlaces(a,d)
for i in range(len(a)):
    print(a[i], end=" ")
# Out:
# 5 6 7 1 2 3 4

# %% [markdown]
# # Move all Zeros to End of Array
#
# Given an array of integers arr[], move all the zeros to the end of the array while maintaining the relative order of all non-zero elements.
#
# Examples:
#
# Input: arr[] = [1, 2, 0, 4, 3, 0, 5, 0]
# Output: [1, 2, 4, 3, 5, 0, 0, 0]
# Explanation: There are three 0s that are moved to the end.
#
# Input: arr[] = [10, 20, 30]
# Output: [10, 20, 30]
# Explanation: No change in array as there are no 0s.
#
# Input: arr[] = [0, 0]
# Output: [0, 0]
# Explanation: No change in array as there are all 0s.

# %%
#Brute Force Solution
def pushZerosToEnd(a):
    n=len(a)
    temp=[0]*n
    j=0
    for i in range(n):
        if a[i] != 0:
            temp[j]=a[i]
            j+=1
    while j<n:
        temp[j]=0
        j+=1
    for i in range(n):
        a[i]=temp[i]
arr = [1, 2, 0, 4, 3, 0, 5, 0]
pushZerosToEnd(arr)

for num in arr:
    print(num, end=" ")

# [Naive Approach] Using Temporary Array - O(n) Time and O(n) Space
# The idea is to create a temporary array of same size as the input array arr[].

# First, copy all non-zero elements from arr[] to the temporary array.
# Then, fill all the remaining positions in temporary array with 0.
# Finally, copy all the elements from temporary array to arr[].
# Out:
# 1 2 4 3 5 0 0 0

# %%
# [Better Approach] Two Traversals
# The idea is to move all the zeros to the end of the array while maintaining the 
#     relative order of non-zero elements using two traversals.

# First Traversal: Shift non-zero elements

# Traverse the array and maintain the count of non-zero elements. This count is 
# initialized with 0 and keeps track of where the next non-zero element should be 
# placed in the array.
# If the element is non-zero, place it at arr[count] and increment count by 1.
# After traversing all the elements, all non-zero elements will be shifted to the front
# while maintaining their original order.
# Second Traversal: Fill remaining positions with zeros

# After the first traversal, all non-zero elements will be at the start of the array and 
# count will store the index where the first zero should be placed.
# Iterate from count to the end of array and fill all indices with 0.

def moveZeroesToEnd(a):
    n=len(a)
    idx=0
    for i in range(n):
        if a[i]!=0:
            a[idx]=a[i]
            idx+=1
    for i in range(idx,n):
        a[idx]=0
arr = [1, 2, 0, 4, 3, 0, 5, 0]
pushZerosToEnd(arr)

for num in arr:
    print(num, end=" ")
# Time Complexity: O(n), as we are traversing the array only twice.
# Auxiliary Space: O(1)
# Out:
# 1 2 4 3 5 0 0 0

# %%
# [Expected Approach] One Traversal
# The idea is similar to the previous approach where we took a pointer, 
# say count to track where the next non-zero element should be placed. However, 
# on encountering a non-zero element, instead of directly placing the non-zero element at arr[count],
# we will swap the non-zero element with arr[count]. This will ensure that if there is any zero present at arr[count], 
# it is pushed towards the end of array and is not overwritten.

def pushZerosToEnd(a):
    n=len(a)
    count=0
    for i in range(n):
        if a[i]!=0:
            a[i],a[count]=a[count],a[i]
            count+=1
arr = [1, 2, 0, 4, 3, 0, 5, 0]
pushZerosToEnd(arr)

for num in arr:
    print(num, end=" ")
# Time Complexity: O(n), as we are traversing the array only once.
# Auxiliary Space: O(1)
# Out:
# 1 2 4 3 5 0 0 0

# %% [markdown]
# # Minimum increment by k operations to make all equal
#
# You are given an array of n-elements, you have to find the number of operations needed to make all elements of array equal. Where a single operation can increment an element by k. If it is not possible to make all elements equal print -1.
#
# Example :
#
# Input : arr[] = {4, 7, 19, 16},  k = 3
# Output : 10
#
# Input : arr[] = {4, 4, 4, 4}, k = 3
# Output : 0
#
# Input : arr[] = {4, 2, 6, 8}, k = 3
# Output : -1

# %%
def minKinc(a,k):
    n=len(a)
    res=0
    maxEle=max(a)
    for i in range(n):
        if (maxEle-a[i])%k!=0:
            return -1
        else:
            res+=(maxEle-a[i])//k
    return res
k = 6
a = [21, 33, 9, 45, 63] 
print(minKinc(a,k))
# Time Complexity: O(n)
# Auxiliary Space: O(1)

# To solve this question we require to check whether all elements can became equal or 
# not and that too only by incrementing k from elements value. For this we have to check that 
# the difference of any two elements should always be divisible by k. If it is so, then all elements
# can become equal otherwise they can not became equal in any case by incrementing k from them. Also, 
# the number of operations required can be calculated by finding value of (max - Ai)/k for all elements. 
# where max is maximum element of array.

# Algorithm : 

# // iterate for all elements
# for (int i=0; i<n; i++)
# {
#     // check if element can make equal to max
#     //  or not if not then return -1
#     if ((max - arr[i]) % k != 0 )
#         return -1;

#     // else update res for required operations
#     else
#         res += (max - arr[i]) / k ;
# }

# return res;
# Out:
# 24

# %% [markdown]
# # Minimum cost to make array size 1 by removing larger of pairs
#
# Given an array of n integers. We need to reduce size of array to one. We are allowed to select a pair of integers and remove the larger one of these two. This decreases the array size by 1. Cost of this operation is equal to value of smallest one. Find out minimum sum of costs of operations needed to convert the array into a single element.
#
# Examples:
#
# Input: arr[]= [4 ,3 ,2 ]
# Output: 4
# Explanation: Choose (4, 2) so 4 is removed, new array = {2, 3}. Now choose (2, 3) so 3 is removed.  So total cost = 2 + 2 = 4.
#
# Input: arr[]=[ 3, 4 ]
# Output: 3
# Explanation: choose (3, 4) so cost is 3.

# %%
# Greedy Approach - Time O(n) and Space O(1)
# The idea is to always pick the minimum value as part of the pair and remove larger value.
# This minimizes cost of reducing array to size 1

def mincost(a):
    n=len(a)
    return (n-1)*min(a)
print(mincost([4,2,3]))
# Out:
# 4
